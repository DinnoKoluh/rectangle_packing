# %%
#!pip3 install z3-solver
from z3 import *
# %load_ext autoreload
# %autoreload 2
from funs_smt import *
#%config InlineBackend.figure_format = 'svg' # show images as svg
import matplotlib.pyplot as plt
import random
import copy
import time
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# No rotations

# %%
rot = False
t1 = time.time()
num = 7 #instance number
solve_problem(num)
t2 = time.time()
print("Time needed: " + str(t2 - t1))
visualize(num, rot)
# Out:
# Height Iteration AvailableArea Width
# 16 0 28 14
# 15 1 14 14
# 14 2 0 14
# Time needed: 0.7775154113769531

# %% [markdown]
# With rotations

# %%
rot = True
t1 = time.time()
num = 10
r = solve_problem_rot(num)
t2 = time.time()
print("Time needed: " + str(t2 - t1))
visualize(num, rot, r)
# Out:
# Height Iteration AvailableArea Width
# 23 0 102 17
# 22 1 85 17
# 21 2 68 17
# 20 3 51 17
# 19 4 34 17
# 18 5 17 17
# 17 6 0 17
# Time needed: 5.014885425567627
# [False, False, False, True, False, True, False, True, False, True, True, False]
